# %%
# !git clone https://github.com/Mirwaisse/SRCNN
# Out:
# Cloning into 'SRCNN'...
# remote: Enumerating objects: 415, done.
# remote: Total 415 (delta 0), reused 0 (delta 0), pack-reused 415
# Receiving objects: 100% (415/415), 61.20 MiB | 22.34 MiB/s, done.

# %%
import os
os.chdir('SRCNN')

# %%
# !ls
# Out:
# 1_original.jpg	model_126.pth  model_158.pth  model_18.pth   model_40.pth  model_72.pth
# 2_bicubic.jpg	model_127.pth  model_159.pth  model_190.pth  model_41.pth  model_73.pth
# 3_srcnn.jpg	model_128.pth  model_15.pth   model_191.pth  model_42.pth  model_74.pth
# data		model_129.pth  model_160.pth  model_192.pth  model_43.pth  model_75.pth
# data.py		model_12.pth   model_161.pth  model_193.pth  model_44.pth  model_76.pth
# main.py		model_130.pth  model_162.pth  model_194.pth  model_45.pth  model_77.pth
# model_0.pth	model_131.pth  model_163.pth  model_195.pth  model_46.pth  model_78.pth
# model_100.pth	model_132.pth  model_164.pth  model_196.pth  model_47.pth  model_79.pth
# model_101.pth	model_133.pth  model_165.pth  model_197.pth  model_48.pth  model_7.pth
# model_102.pth	model_134.pth  model_166.pth  model_198.pth  model_49.pth  model_80.pth
# model_103.pth	model_135.pth  model_167.pth  model_199.pth  model_4.pth   model_81.pth
# ...

# %%
# !python main.py --zoom_factor 3 --nb_epoch 200 --cuda
# Out:
# Epoch 0. Training loss: 0.21591969283800277
# Average PSNR: 9.12838654772876 dB.
# Epoch 1. Training loss: 0.059009842574596405
# Average PSNR: 15.688322199616778 dB.
# Epoch 2. Training loss: 0.025590040188814913
# Average PSNR: 15.992575600986758 dB.
# Epoch 3. Training loss: 0.023256947508170492
# Average PSNR: 16.476470357844534 dB.
# Epoch 4. Training loss: 0.020531755265971972
# Average PSNR: 17.069799349618332 dB.
# Epoch 5. Training loss: 0.01747960484926663
# Average PSNR: 17.829813855454173 dB.
# Epoch 6. Training loss: 0.014844544180151489
# Average PSNR: 18.506636335704698 dB.
# Epoch 7. Training loss: 0.01285730211419009
# Average PSNR: 19.14276515454249 dB.
# Epoch 8. Training loss: 0.011289939594765505
# Average PSNR: 19.69482632350408 dB.
# Epoch 9. Training loss: 0.010054829737378491
# Average PSNR: 20.151835219625532 dB.
# Epoch 10. Training loss: 0.009288087213737152
# Average PSNR: 20.562246831894203 dB.
# Epoch 11. Training loss: 0.00851962197985914
# ...

# %%
os.chdir('..')

# %%
# !ls
# Out:
# sample_data  SRCNN  test.jpg  zoomed_test.jpg

# %%
# !python SRCNN/run.py --zoom_factor 3 --model SRCNN/model_199.pth --image test.jpg
# Out:
# cpu
